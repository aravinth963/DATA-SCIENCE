# %%
import pandas as pd

# %% [markdown]
# # Level 1

# %%
import pandas as pd

data = {
    "Name":["Arun","Bala","Charan","Divya","Esha"],
    "Age":[21,22,20,23,21],
    "Department":["IT","HR","IT","Sales","HR"],
    "Salary":[45000,35000,50000,42000,37000]
}

df = pd.DataFrame(data)

# %%
#Display the first 3 rows.

df.head(3)
# Out:
#      Name  Age Department  Salary
# 0    Arun   21         IT   45000
# 1    Bala   22         HR   35000
# 2  Charan   20         IT   50000

# %%
#Display the last 2 rows.
df.tail(2)
# Out:
#     Name  Age Department  Salary
# 3  Divya   23      Sales   42000
# 4   Esha   21         HR   37000

# %%
#Print only the Name column.
df["Name"]
# Out:
# 0      Arun
# 1      Bala
# 2    Charan
# 3     Divya
# 4      Esha
# Name: Name, dtype: str

# %%
#Print Name and Salary.

df[["Name","Salary"]]
# Out:
#      Name  Salary
# 0    Arun   45000
# 1    Bala   35000
# 2  Charan   50000
# 3   Divya   42000
# 4    Esha   37000

# %%
#Find the shape of the dataframe.

df.shape
# Out:
# (5, 4)

# %%
#Display column names.

df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
#Find the data type of every column.

df.dtypes
# Out:
# Name            str
# Age           int64
# Department      str
# Salary        int64
# dtype: object

# %%
#Print all employees whose salary is greater than 40000.

df[df["Salary"] > 40000]
# Out:
#      Name  Age Department  Salary
# 0    Arun   21         IT   45000
# 2  Charan   20         IT   50000
# 3   Divya   23      Sales   42000

# %%
#Print employees from the IT department.

df[df["Department"] == "IT"]
# Out:
#      Name  Age Department  Salary
# 0    Arun   21         IT   45000
# 2  Charan   20         IT   50000

# %%
#Find the average salary.

df["Salary"].mean() #41800.00
int(df["Salary"].mean())
# Out:
# 41800

# %% [markdown]
# # Level 2

# %%
#Employees whose age is greater than 21.

df[df["Age"] > 21]
# Out:
#     Name  Age Department  Salary
# 1   Bala   22         HR   35000
# 3  Divya   23      Sales   42000

# %%
#Employees whose department is HR.

df[df["Department"] == "HR"]
# Out:
#    Name  Age Department  Salary
# 1  Bala   22         HR   35000
# 4  Esha   21         HR   37000

# %%
#Employees with salary between 35000 and 45000.

df[(df["Salary"] > 35000) & (df["Salary"] < 45000)]
# Out:
#     Name  Age Department  Salary
# 3  Divya   23      Sales   42000
# 4   Esha   21         HR   37000

# %%
#Employees whose department is IT and salary > 45000.

df[(df["Department"]=="IT") & (df["Salary"] > 45000)]
# Out:
#      Name  Age Department  Salary
# 2  Charan   20         IT   50000

# %%
#Employees whose department is HR or Sales.

df[(df["Department"] == "HR") | (df["Department"] == "Sales")]
# Out:
#     Name  Age Department  Salary
# 1   Bala   22         HR   35000
# 3  Divya   23      Sales   42000
# 4   Esha   21         HR   37000

# %%
#Employees whose name starts with "A".

df[df["Name"].str.startswith("A")]
# Out:
#    Name  Age Department  Salary
# 0  Arun   21         IT   45000

# %%
#Employees whose name ends with "a".

df[df["Name"].str.startswith("a")]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Department, Salary]
# Index: []

# %%
#Employees whose age is 21 or 23.

df[(df["Age"] == 21) | (df["Age"] == 23)]
# Out:
#     Name  Age Department  Salary
# 0   Arun   21         IT   45000
# 3  Divya   23      Sales   42000
# 4   Esha   21         HR   37000

# %%
#Find employees whose salary is not equal to 42000.

df[df["Salary"] != 42000]
# Out:
#      Name  Age Department  Salary
# 0    Arun   21         IT   45000
# 1    Bala   22         HR   35000
# 2  Charan   20         IT   50000
# 4    Esha   21         HR   37000

# %%
#Sort employees by salary in ascending order.

df.sort_values("Salary",ascending=False)
# Out:
#      Name  Age Department  Salary
# 2  Charan   20         IT   50000
# 0    Arun   21         IT   45000
# 3   Divya   23      Sales   42000
# 4    Esha   21         HR   37000
# 1    Bala   22         HR   35000

# %% [markdown]
# # Level 3

# %%
#Find maximum salary.

max(df["Salary"])
# Out:
# 50000

# %%
#Find minimum salary.

min(df["Salary"])
# Out:
# 35000

# %%
#Find median salary.

df["Salary"].median()
# Out:
# np.float64(42000.0)

# %%
#Find standard deviation of salary.

df["Salary"].std()
# Out:
# np.float64(6058.052492344384)

# %%
#Count total employees

df["Name"].count()
df["Name"].nunique()
# Out:
# 5

# %%
#Count employees in each department.

df["Department"].value_counts()
# Out:
# Department
# IT       2
# HR       2
# Sales    1
# Name: count, dtype: int64

# %%
#Find total salary paid.

df["Salary"].sum()
# Out:
# np.int64(209000)

# %%
#Find average age.

int(df["Age"].mean())
# Out:
# 21

# %%
#Find the employee with highest salary.

df.nsmallest(1,"Salary")
df.nsmallest(2, "Salary").tail(1)
#df.loc[df["Salary"].idxmax()]
# Out:
#    Name  Age Department  Salary
# 4  Esha   21         HR   37000

# %%
#Find the employee with lowest salary.

df.loc[df["Salary"].idxmin()]
# Out:
# Name           Bala
# Age              22
# Department       HR
# Salary        35000
# Name: 1, dtype: object

# %% [markdown]
# # Level 4

# %%
#Find average salary department-wise.

df.groupby("Department")["Salary"].mean()
# Out:
# Department
# HR       36000.0
# IT       47500.0
# Sales    42000.0
# Name: Salary, dtype: float64

# %%
#Find maximum salary department-wise.

df.groupby("Department")["Salary"].max()
# Out:
# Department
# HR       37000
# IT       50000
# Sales    42000
# Name: Salary, dtype: int64

# %%
#Count employees department-wise.

df.groupby("Department")["Department"].count()
# Out:
# Department
# HR       2
# IT       2
# Sales    1
# Name: Department, dtype: int64

# %%
#Find total salary department-wise.

df.groupby("Department")["Salary"].sum()
# Out:
# Department
# HR       72000
# IT       95000
# Sales    42000
# Name: Salary, dtype: int64

# %%
#Find minimum age department-wise.

df.groupby("Department")["Age"].min()
# Out:
# Department
# HR       21
# IT       20
# Sales    23
# Name: Age, dtype: int64

# %%
#Find average age department-wise.

df.groupby("Department")["Age"].mean()
# Out:
# Department
# HR       21.5
# IT       20.5
# Sales    23.0
# Name: Age, dtype: float64

# %%
#Find department having highest average salary.

df.groupby("Department")["Salary"].mean().idxmax()
# Out:
# 'IT'

# %%
#Find department with maximum employees.

df.groupby("Department")["Salary"].count().idxmax()
# Out:
# 'HR'
