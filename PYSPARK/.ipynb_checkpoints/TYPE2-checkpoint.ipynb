# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Type2").master("local[*]").getOrCreate()

dimension_df = spark.read.csv("/home/ramanaravinth/DATA SCIENCE/PYSPARK/SCD/customer_dimension.csv",header = True,inferSchema = True)

source_df = spark.read.csv("/home/ramanaravinth/DATA SCIENCE/PYSPARK/SCD/customer_source.csv",header = True,inferSchema = True)

joined_df = source_df.alias("src").join(dimension_df.alias("dim"),on="customer_id",how="inner").show()
# Out:
# +-----------+-------------+-----------+----------+-------------------+-------------+-----------+----------+------------------+----------+--------+----------+
# |customer_id|customer_name|       city|     phone|              email|customer_name|       city|     phone|             email|start_date|end_date|is_current|
# +-----------+-------------+-----------+----------+-------------------+-------------+-----------+----------+------------------+----------+--------+----------+
# |        101|     Aravinth|  Bangalore|9876543210| aravinth@gmail.com|     Aravinth|    Chennai|9876543210|aravinth@gmail.com|2024-01-01|    NULL|      true|
# |        102|        Priya|  Bangalore|9999999999|    priya@gmail.com|        Priya|  Bangalore|9123456780|   priya@gmail.com|2024-01-01|    NULL|      true|
# |        103|        Rahul|  Hyderabad|9988776655|rahul_new@gmail.com|        Rahul|  Hyderabad|9988776655|   rahul@gmail.com|2024-01-01|    NULL|      true|
# ...
