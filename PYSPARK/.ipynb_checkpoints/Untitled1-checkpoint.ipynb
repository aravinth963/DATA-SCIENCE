# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("joins").master("local[*]").getOrCreate()

students = [
    (1, "Arun"),
    (2, "Bala"),
    (3, "Charan")
]

marks = [
    (1, 90),
    (2, 85),
    (4, 70)
]

students_1 = spark.createDataFrame(students,["id"],["name"]).show()
marks_1 = spark.createDataFrame(marks,["id"],["marks"]).show()
# Out:
# +---+------+
# | id|    _2|
# +---+------+
# |  1|  Arun|
# |  2|  Bala|
# |  3|Charan|
# +---+------+
#
# +---+---+
# | id| _2|
# +---+---+
# |  1| 90|
# |  2| 85|
# |  4| 70|
# +---+---+
